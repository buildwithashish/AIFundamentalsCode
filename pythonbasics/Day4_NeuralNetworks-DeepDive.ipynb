# %%
#Formula for weights intialization for a neuron

import numpy as np

n_inputs = 4
n_neurons = 2

#He intialization (a.k.a. Kaiming Initialization)
W_hidden = np.random.randn(n_neurons, n_inputs) * np.sqrt(2 / n_inputs)
print("HE : \n", W_hidden)

print("\n")

#Xavier Initialization (a.k.a. Glorot Initialization)
XW_weights = np.random.randn(n_neurons, n_inputs) * np.sqrt(1 / n_inputs)
print("XAVIER :\n ", XW_weights)
# Out:
# HE :
#  [[ 0.77933731  0.64317564  0.53337634 -0.51584379]
#  [-0.36950279 -2.06137261  0.30536575 -0.16749772]]
#
#
# XAVIER :
#   [[ 0.90160413  0.4233966   0.37155764 -0.62093783]
#  [ 0.1928984  -0.88943356  0.54606661 -0.46026977]]

# %%
#TRaining Model end to end

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# Step 1: Training data (dummy)
X = np.array([
    [2, 3, 70, 6],
    [10, 4, 95, 7],
    [3, 5, 65, 8],
    [12, 8, 60, 9],
    [7, 6, 80, 6]
], dtype=np.float32)

y = np.array([
    [0],  # Not hired
    [0],  # Not hired
    [1],  # Hired
    [1],  # Hired
    [1]   # Hired
], dtype=np.float32)

# Step 2: Build the model
model = Sequential([
    Dense(2, input_shape=(4,), activation='relu'),   # Hidden layer with 2 neurons
    Dense(1, activation='sigmoid')                    # Output layer
])

# Step 3: Compile
model.compile(optimizer=SGD(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# Step 4: Train
model.fit(X, y, epochs=100, verbose=1)

# Step 5: Predict a new candidate
new_candidate = np.array([[8, 7, 75, 7]], dtype=np.float32)
prediction = model.predict(new_candidate)
print("Probability of hire:", prediction[0][0])
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4000 - loss: 0.6931
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6000 - loss: 0.6930
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6000 - loss: 0.6929
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6000 - loss: 0.6928
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6000 - loss: 0.6928
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6000 - loss: 0.6927
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6000 - loss: 0.6926
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6000 - loss: 0.6925
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6000 - loss: 0.6924
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6000 - loss: 0.6923
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6000 - loss: 0.6922
# Epoch 12/100
# ...

# %%
#Training model end to end and plot the graph

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# 1. Data (dummy)
X = np.array([
    [2, 3, 70, 6],
    [10, 4, 95, 7],
    [3, 5, 65, 8],
    [12, 8, 60, 9],
    [7, 6, 80, 6],
    [4, 2, 90, 5],
    [6, 7, 55, 7]
], dtype=np.float32)

y = np.array([
    [0],  # Not hired
    [0],  # Not hired
    [1],  # Hired
    [1],  # Hired
    [1],  # Hired
    [0],  # Not hired
    [1]   # Hired
], dtype=np.float32)

# 2. Define model
model = Sequential([
    Dense(2, input_shape=(4,), activation='relu'),
    Dense(1, activation='sigmoid')
])

# 3. Compile
model.compile(optimizer=SGD(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# 4. Train with validation_split
history = model.fit(
    X, y,
    epochs=100,
    validation_split=0.3,  # 30% used for validation
    verbose=1
)

# 5. Plot accuracy and loss
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.5000 - loss: 1.0889 - val_accuracy: 0.3333 - val_loss: 4.6521
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5000 - loss: 3.2309 - val_accuracy: 0.6667 - val_loss: 0.8046
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5000 - loss: 1.0596 - val_accuracy: 0.3333 - val_loss: 3.7138
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5000 - loss: 2.5743 - val_accuracy: 0.6667 - val_loss: 0.7528
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5000 - loss: 0.9754 - val_accuracy: 0.3333 - val_loss: 2.7408
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5000 - loss: 1.8957 - val_accuracy: 0.6667 - val_loss: 0.7830
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5000 - loss: 1.0230 - val_accuracy: 0.3333 - val_loss: 2.2601
# Epoch 8/100
# ...

# %%
#Training model end to end and early stopping if the training has stopped improving
from tensorflow.keras.callbacks import EarlyStopping

# Define early stopping: monitor val_loss, stop if it doesn’t improve for 5 epochs
early_stop = EarlyStopping(
    monitor='val_loss',     # What to monitor
    patience=5,             # Wait 5 epochs with no improvement
    restore_best_weights=True  # Roll back to best model
)

# Add the callback to model.fit
history = model.fit(
    X, y,
    epochs=100,
    validation_split=0.3,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1849 - val_accuracy: 0.6667 - val_loss: 0.9766
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7500 - loss: 0.2686 - val_accuracy: 1.0000 - val_loss: 0.1032
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.1825 - val_accuracy: 0.6667 - val_loss: 0.9782
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7500 - loss: 0.2632 - val_accuracy: 1.0000 - val_loss: 0.1037
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.1798 - val_accuracy: 0.6667 - val_loss: 0.9799
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7500 - loss: 0.2571 - val_accuracy: 1.0000 - val_loss: 0.1044
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1767 - val_accuracy: 0.6667 - val_loss: 0.9816

# %%
#Full example with early stopping, best weights are restored and plotted graphs
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# 1. Sample dataset (same structure, slightly extended)
X = np.array([
    [2, 3, 70, 6],
    [10, 4, 95, 7],
    [3, 5, 65, 8],
    [12, 8, 60, 9],
    [7, 6, 80, 6],
    [4, 2, 90, 5],
    [6, 7, 55, 7],
    [9, 5, 82, 6],
    [11, 6, 78, 5],
    [5, 3, 88, 7]
], dtype=np.float32)

y = np.array([
    [0], [0], [1], [1], [1],
    [0], [1], [1], [0], [1]
], dtype=np.float32)

# 2. Model definition
model = Sequential([
    Dense(2, input_shape=(4,), activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# 3. Early stopping callback
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# 4. Train with validation
history = model.fit(
    X, y,
    epochs=100,
    validation_split=0.3,
    callbacks=[early_stop],
    verbose=1
)

# 5. Visualize loss and accuracy
plt.figure(figsize=(12, 4))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.4286 - loss: 0.9349 - val_accuracy: 0.6667 - val_loss: 0.6859
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1429 - loss: 0.9272 - val_accuracy: 0.6667 - val_loss: 0.6851
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1429 - loss: 0.9196 - val_accuracy: 0.6667 - val_loss: 0.6843
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1429 - loss: 0.9122 - val_accuracy: 0.6667 - val_loss: 0.6837
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1429 - loss: 0.9050 - val_accuracy: 0.6667 - val_loss: 0.6832
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.0000e+00 - loss: 0.8974 - val_accuracy: 0.6667 - val_loss: 0.6828
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.0000e+00 - loss: 0.8891 - val_accuracy: 1.0000 - val_loss: 0.6832
# Epoch 8/100
# ...

# %%
#Breast cancer classifier

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# 1. Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# 2. Preprocess
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# 3. Define model
model = Sequential([
    Dense(16, input_shape=(X.shape[1],), activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

# 4. Compile with Adam optimizer
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# 5. Early stopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# 6. Train
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    callbacks=[early_stop],
    verbose=1
)

# 7. Plot accuracy and loss
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# 8. Predict on a few samples
sample = X_val[:5]
predictions = model.predict(sample)
print("\nPredicted probabilities:", predictions.flatten())
print("Actual labels         :", y_val[:5])
# Out:
# Epoch 1/100
# /Users/asgupta6/code/cisco/storm-eng/SensitiveInfoScanner-Ashish/tf-env/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6476 - loss: 0.6253 - val_accuracy: 0.7281 - val_loss: 0.5581
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7865 - loss: 0.5310 - val_accuracy: 0.8333 - val_loss: 0.4718
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.4515 - val_accuracy: 0.8860 - val_loss: 0.3987
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.3965 - val_accuracy: 0.9298 - val_loss: 0.3400
# Epoch 5/100
# ...

# %%
#Confusion matrix

from sklearn.metrics import confusion_matrix, classification_report

# Predict on all validation data (use 0.5 threshold)
y_pred_probs = model.predict(X_val)
y_pred = (y_pred_probs > 0.5).astype(int)  # Convert probabilities to 0 or 1

# 1. Confusion matrix
cm = confusion_matrix(y_val, y_pred)
print("Confusion Matrix:\n", cm)

# 2. Classification report
print("\nClassification Report:\n", classification_report(y_val, y_pred, target_names=["Benign", "Malignant"]))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Confusion Matrix:
#  [[40  3]
#  [ 3 68]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.93      0.93      0.93        43
#    Malignant       0.96      0.96      0.96        71
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
#Matrix heatmap

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Predict and binarize
y_pred_probs = model.predict(X_val)
y_pred = (y_pred_probs > 0.5).astype(int)

# Confusion matrix
cm = confusion_matrix(y_val, y_pred)
print("Confusion Matrix:\n", cm)

# Plot heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Pred: Benign', 'Pred: Malignant'],
            yticklabels=['Actual: Benign', 'Actual: Malignant'])

plt.title("Confusion Matrix")
plt.xlabel("Prediction")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Confusion Matrix:
#  [[40  3]
#  [ 3 68]]

# %%
#Visulaize precision, recall and F1-score

from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

metrics = {'Precision': precision, 'Recall': recall, 'F1-Score': f1}

plt.figure(figsize=(6, 4))
sns.barplot(x=list(metrics.keys()), y=list(metrics.values()), palette='crest')
plt.title("Model Evaluation Metrics")
plt.ylim(0.0, 1.1)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/85/kg2v2y7n1vv0w6mlrdpgrwfc0000gn/T/ipykernel_90072/572117751.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(metrics.keys()), y=list(metrics.values()), palette='crest')

# %%
just tell m
